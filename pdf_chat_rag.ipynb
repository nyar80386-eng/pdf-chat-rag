# %% [markdown]
# <a href="https://colab.research.google.com/github/nyar80386-eng/pdf-chat-rag/blob/main/pdf_chat_rag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U langchain langchain-community langchain-google-genai langchain-text-splitters chromadb pypdf sentence-transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.7/163.7 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 50.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.6/81.6 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 75.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.5/395.5 kB 33.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 740.6/740.6 kB 49.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 21.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 69.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 114.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 68.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import userdata
import os

os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')
print("Gemini API key loaded!")
# Out:
# Gemini API key loaded!

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-1a5f5a46-1526-4905-8f7a-55c4212086bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a5f5a46-1526-4905-8f7a-55c4212086bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

file_name = list(uploaded.keys())[0]
loader = PyPDFLoader(file_name)
pages = loader.load()
print(f"Total pages loaded: {len(pages)}")

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = text_splitter.split_documents(pages)
print(f"Total chunks created: {len(chunks)}")
# Out:
# /tmp/ipykernel_664/978830113.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# Total pages loaded: 21
# Total chunks created: 171

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
vectorstore = Chroma.from_documents(documents=chunks, embedding=embeddings)
print("Vector database ban gaya!")
# Out:
# /tmp/ipykernel_664/1630358664.py:4: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-3.6-flash", temperature=0)
print("Chatbot ready hai!")
# Out:
# Chatbot ready hai!

# %%
question = "is document ka main topic kya hai?"

relevant_docs = vectorstore.similarity_search(question, k=3)
context = "\n\n".join([doc.page_content for doc in relevant_docs])

prompt = f"""Neeche diye gaye document ke context ka use karke sawal ka jawab do.

Context:
{context}

Sawal: {question}

Jawab:"""

response = llm.invoke(prompt)
print("Jawab:")
print(response.content)
# Out:
# /usr/local/lib/python3.13/dist-packages/langchain_google_genai/chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# Jawab:
# [{'type': 'text', 'text': 'Is document ka main topic **Large Language Models (LLMs) aur Natural Language Models (NLMs)** ke vikas aur unki training prakriya hai. \n\nIsme vishesh roop se nimnlikhit baaton par charcha ki gayi hai:\n1. **Model Scaling:** Google Shard (GShard) aur GLaM jaise bade language models ke parameters ka scale badhna.\n2. **Symbolic Knowledge Distillation:** Bade models ka upayog karke chhote models ko train karne ki technique.\n3. **Pretraining Process:** Data collection (general aur specialized sources) aur data preprocessing (filtering, deduplication, privacy protection, aur tokenization).', 'extras': {'signature': '...'}}]

# %%
question = "is document ka main topic kya hai?"

relevant_docs = vectorstore.similarity_search(question, k=3)
context = "\n\n".join([doc.page_content for doc in relevant_docs])

prompt = f"""Neeche diye gaye document ke context ka use karke sawal ka jawab do.

Context:
{context}

Sawal: {question}

Jawab:"""

response = llm.invoke(prompt)

# Sirf clean text nikalo
if isinstance(response.content, list):
    answer = response.content[0]['text']
else:
    answer = response.content

print("Jawab:")
print(answer)
# Out:
# /usr/local/lib/python3.13/dist-packages/langchain_google_genai/chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# Jawab:
# Is document ka main topic **Large Language Models (LLMs) aur Natural Language Models (NLMs)** ke vikas, unki training aur scaling processes par aadharit hai.
#
# Isme mukhya roop se nimnlikhit baaton par charcha ki gayi hai:
# 1. **Language Models ka Scaling aur Size:** GShard aur GLaM jaise models ka 100 billion se trillion-parameter scale tak pahunchna aur scaling laws.
# 2. **Pretraining Process:** Dataset ki collection (general aur specialized data), preprocessing, deduplication, privacy protection, aur tokenization.
# 3. **Training Techniques:** Symbolic knowledge distillation aur chhote models ko ache se train karne ke tareeqe.
